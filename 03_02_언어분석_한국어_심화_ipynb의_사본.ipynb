# %% [markdown]
# <a href="https://colab.research.google.com/github/taegujun/HUFS_Project_Bluehouse/blob/main/03_02_%EC%96%B8%EC%96%B4%EB%B6%84%EC%84%9D_%ED%95%9C%EA%B5%AD%EC%96%B4_%EC%8B%AC%ED%99%94_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 환경 준비

# %%
# konlpy(한국어형태소분석기)를 실행하기
import konlpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-da77d63596bb> in <module>()
#       1 # konlpy(한국어형태소분석기)를 실행하기
# ----> 2 import konlpy
#
# ModuleNotFoundError: No module named 'konlpy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# konlpy 설치하기 ## https://data1000.tistory.com/33
# !pip3 install jpype1==0.7.0
# !pip3 install konlpy
# Out:
# Collecting jpype1==0.7.0
#   Downloading https://files.pythonhosted.org/packages/07/09/e19ce27d41d4f66d73ac5b6c6a188c51b506f56c7bfbe6c1491db2d15995/JPype1-0.7.0-cp36-cp36m-manylinux2010_x86_64.whl (2.7MB)
#      |████████████████████████████████| 2.7MB 5.8MB/s
# Installing collected packages: jpype1
# Successfully installed jpype1-0.7.0
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 1.2MB/s
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (0.7.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Collecting tweepy>=3.7.0
#   Downloading https://files.pythonhosted.org/packages/bb/7c/99d51f80f3b77b107ebae2634108717362c059a41384a1810d13e2429a81/tweepy-3.9.0-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.18.5)
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 6.2MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.11.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Installing collected packages: colorama, tweepy, beautifulsoup4, konlpy
#   Found existing installation: tweepy 3.6.0
#     Uninstalling tweepy-3.6.0:
#       Successfully uninstalled tweepy-3.6.0
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2 tweepy-3.9.0

# %%
# konlpy를 실행하기
import konlpy

# %%
## pandas을 실행하기, 단 실행 별명을 pd로
import pandas as pd

# %% [markdown]
# # 데이터 불러오기

# %%
# 구글 드라이브 연결을 위한 기본 세팅 
# !pip install -U -q PyDrive
 
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
## 문서 ID로 실제 파일 불러오기
# 실습을 위한 역대 대통령 취임사: 노무현, 이명박, 박근혜, 문재인
## https://drive.google.com/file/d/1tRocuFYGwq9M5xE0KIdnNI5FdK-p-FEi/view?usp=sharing

rawdata_downloaded = drive.CreateFile({'id': '1tRocuFYGwq9M5xE0KIdnNI5FdK-p-FEi'})
rawdata_downloaded.GetContentFile('rawdata_2.csv')

# %%
# "rawdata.txt" 파일의 내용을 "원본데이터" 변수로 불러오기
원본데이터 = pd.read_csv('rawdata_2.csv', sep=",")

# %%
# "원본데이터" 변수 내용 확인하기
원본데이터
# Out:
#     number  category                                           contents
# 0   1,001      육아/교육  올해 보육료가 오르지 않았는데 맞춤형보육이라고 보육료를 깍고 교사인건비는 올해 9 ...
# 1   1,002       보건복지  군입대전정신병검사정상 군입대전 정신과병원진룍기록없습니다.개월앞두고 극심한 스트레스로...
# 2   1,003      육아/교육  <유아교육법 제 24조에서는\n 1) 초등학교 취학직전 3년의 유아교육은 무상으로 ...
# 3   1,004   외교/통일/국방  "이라며 "문재인대통령님과 문재인 정부의 힘은 한미 결속에서 생기는 것이고 대화로 ...
# 4   1,005       보건복지  포털을 검색하다가 독립유공자 유족범위를 (손)자로 한정한 법령은 위헌이라는 판결이 ...
# 5   1,006      육아/교육  먼저 감사드립니다. 국민들의 아픈곳을 만져주시고자   이 자리를 만들어 주시는 대통...
# 6   1,007   외교/통일/국방  차례\n-러시아 PNG가 한반도를 경유해야 하는 8번째 이유\n-러시아 가스공급이 ...
# 7   1,008       농산어촌  안녕하십니까 \n저는 서울의 한 요양병원에서 근무 중인 당직 의사로\n저희 요양병원...
# 8   1,009       정치개혁  안녕하세요 대통령님! 이글을 제가 쓴다고 해서 대통령님께서 볼수있을지 없을지는 모르...
# 9   1,010        일자리  벌써 내일이면 8월도 다가고 9월입니다\n보육도 공교육화 되어야 한다는것에는 동의합...
# 10  1,011      육아/교육  가정어린이 집에서 영아반 교사로  여러 해 동안 일하고 있습니다  적은 보수에도 아...
# 11  1,012      육아/교육  태어난지 한달 도 안되 신생아를 자기 친정 집에서 혼자 방치함.방치이유는 남자와의 ...
# 12  1,013        일자리  아파트 경비원들의 일자리는 노년층의 일자리에 중요한 몫을 담당하고 있다. 그런데 최...
# 13  1,014      육아/교육  안녕하세요..\n경기도 화성시 능동 신동탄파크자이2차 입주예정자 입니다.\n\n오산...
# 14  1,015       보건복지  4기 이상의 전이된 말기 암환자들의 경우 항암신약의 급여화를 기다리는 수년간 항암신...
# 15  1,016      안전/환경  혹시 산업폐기물 매립장을 아시나요?\n서산 지곡면에 들어온다고하는 산업폐기물매립장이...
# 16  1,017       보건복지  안녕하십니까?\n저는 유아교육을 전공하고 가정어린이집을 운영하고있는 원장입니다.\n...
# 17  1,018      육아/교육  소규모 영아중심 어린이집 교사입니다.\n내년에 최저임금 인상안이 발표된 이후 저희는...
# 18  1,019       보건복지  안녕하십니까?\n저는 유아교육을 전공하고 가정어린이집을 운영하고있는 원장입니다.\n...
# 19  1,020         행정  안녕하세요 문재인 대통령님. 더이상 가만히 있다가는 나까지 끔찍한 사건을 당할까봐 ...
# 20  1,021         행정  생리대 안전 검증 위원회 여성환경연대를 빼주시기 바랍니다.\n아래글은 식약처에 민원...

# %% [markdown]
# # 형태소 분석

# %%
# konlpy(한국어형태소분석기) 중에서 Okt 실행하기
from konlpy.tag import Okt
okt = Okt()

# %%
# "원본데이터"를 대상으로 "okt"를 사용해서 형태소 분석하기
저장공간  = []
for index, row in 원본데이터.iterrows(): # 원본데이터의 컬럼(열)을 불러와서 반복할 준비!
    대상텍스트 = row[2] # 분석에서 사용할 텍스트 정보가 있는 열을 지정해준다. 주의! python은 0부터 시작한다!
    분류 = row[1] # 분석에서 사용할 분류 정보가 있는 열을 지정해준다. 주의! python은 0부터 시작한다!
    형태소 = list(okt.pos(대상텍스트)) # okt의 pos 기능을 활용해서 대상 텍스트를 형태소 분리한다.
    형태소종합 = pd.DataFrame.from_records(형태소) # 형태소에 저장된 내용을 데이터프레임 형태로 해서 형태소종합으로 저장한다.
    형태소종합['type'] = 분류 # 형태소종합에 분류정보를 추가한다.
    형태소종합['count'] = 1   # 형태소종합에 카운트정보를 추가한다.   
    저장공간.append(형태소종합) # 형태소종합의 내용을 종합하여 저장한다.

# %%
# "형태소" 변수의 저장 내용 확인
형태소
# Out:
# [('생리대', 'Noun'),
#  ('안전', 'Noun'),
#  ('검증', 'Noun'),
#  ('위원회', 'Noun'),
#  ('여', 'Modifier'),
#  ('성', 'Modifier'),
#  ('환경', 'Noun'),
#  ('연대', 'Noun'),
#  ('를', 'Josa'),
#  ('빼주', 'Noun'),
#  ('시기', 'Noun'),
#  ('바랍니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('아래', 'Noun'),
#  ('글', 'Noun'),
#  ('은', 'Josa'),
#  ('식약처', 'Noun'),
#  ('에', 'Josa'),
#  ('민원', 'Noun'),
#  ('신청', 'Noun'),
#  ('한', 'Josa'),
#  ('글', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('근데', 'Adverb'),
#  ('식약처', 'Noun'),
#  ('를', 'Josa'),
#  ('믿을수가', 'Verb'),
#  ('없어서', 'Adjective'),
#  ('글', 'Noun'),
#  ('을', 'Josa'),
#  ('복사', 'Noun'),
#  ('해서', 'Verb'),
#  ('청원', 'Noun'),
#  ('합니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('여', 'Modifier'),
#  ('성', 'Modifier'),
#  ('환경', 'Noun'),
#  ('연', 'Modifier'),
#  ('대가', 'Noun'),
#  ('낀', 'Verb'),
#  ('생리대', 'Noun'),
#  ('조사', 'Noun'),
#  ('는', 'Josa'),
#  ('신뢰', 'Noun'),
#  ('할수가', 'Verb'),
#  ('없습니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('여', 'Modifier'),
#  ('성', 'Modifier'),
#  ('환경', 'Noun'),
#  ('연대', 'Noun'),
#  ('에', 'Josa'),
#  ('유한킴벌리', 'Noun'),
#  ('생리대', 'Noun'),
#  ('1', 'Number'),
#  ('위', 'Noun'),
#  ('점유', 'Noun'),
#  ('율', 'Noun'),
#  ('임원', 'Noun'),
#  ('이', 'Josa'),
#  ('운영', 'Noun'),
#  ('위원', 'Noun'),
#  ('으로', 'Josa'),
#  ('있는데', 'Adjective'),
#  ('어떻게', 'Adjective'),
#  ('신뢰', 'Noun'),
#  ('할수가', 'Verb'),
#  ('있겠습니까', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('공정하지가', 'Adjective'),
#  ('않습니다', 'Verb'),
#  ('.!', 'Punctuation'),
#  ('만약', 'Noun'),
#  ('이글', 'Noun'),
#  ('을', 'Josa'),
#  ('보고', 'Noun'),
#  ('도', 'Josa'),
#  ('그대로', 'Noun'),
#  ('여', 'Modifier'),
#  ('성', 'Modifier'),
#  ('환경', 'Noun'),
#  ('연', 'Modifier'),
#  ('대가', 'Noun'),
#  ('검증', 'Noun'),
#  ('위원', 'Noun'),
#  ('으로', 'Josa'),
#  ('활동', 'Noun'),
#  ('한다면', 'Verb'),
#  ('.', 'Punctuation'),
#  ('저', 'Noun'),
#  ('는', 'Josa'),
#  ('청와대', 'Noun'),
#  ('게시판', 'Noun'),
#  ('에', 'Josa'),
#  ('이글', 'Noun'),
#  ('을', 'Josa'),
#  ('올릴것이며', 'Verb'),
#  (',', 'Punctuation'),
#  ('또한', 'Noun'),
#  ('인터넷', 'Noun'),
#  ('포탈', 'Noun'),
#  ('사이트', 'Noun'),
#  ('뉴스', 'Noun'),
#  ('에', 'Josa'),
#  ('댓글', 'Noun'),
#  ('도배', 'Noun'),
#  ('해서', 'Verb'),
#  ('국민', 'Noun'),
#  ('들', 'Suffix'),
#  ('에게', 'Josa'),
#  ('알릴', 'Verb'),
#  ('것', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('나중', 'Noun'),
#  ('에', 'Josa'),
#  ('후회', 'Noun'),
#  ('말고', 'Josa'),
#  ('곤란한', 'Adjective'),
#  ('상황', 'Noun'),
#  ('이', 'Josa'),
#  ('오지', 'Noun'),
#  ('않도록', 'Verb'),
#  ('판단', 'Noun'),
#  ('잘', 'VerbPrefix'),
#  ('하십시요', 'Verb'),
#  ('전', 'Noun'),
#  ('한다면', 'Verb'),
#  ('합니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('일', 'Modifier'),
#  ('똑바로', 'Noun'),
#  ('하십시요', 'Verb'),
#  ('!', 'Punctuation')]

# %%
# "형태소종합" 변수의 저장 내용 확인
형태소종합
# Out:
#         0            1 type  count
# 0     생리대         Noun   행정      1
# 1      안전         Noun   행정      1
# 2      검증         Noun   행정      1
# 3     위원회         Noun   행정      1
# 4       여     Modifier   행정      1
# ..    ...          ...  ...    ...
# 133     .  Punctuation   행정      1
# 134     일     Modifier   행정      1
# 135   똑바로         Noun   행정      1
# 136  하십시요         Verb   행정      1
# 137     !  Punctuation   행정      1
#
# [138 rows x 4 columns]

# %%
# "저장공간" 변수의 저장 내용 확인
저장공간
# Out:
# [        0            1   type  count
#  0      올해         Noun  육아/교육      1
#  1     보육료         Noun  육아/교육      1
#  2       가         Josa  육아/교육      1
#  3     오르지         Verb  육아/교육      1
#  4    않았는데         Verb  육아/교육      1
#  ..    ...          ...    ...    ...
#  160    과연         Noun  육아/교육      1
#  161    무엇         Noun  육아/교육      1
#  162    인지         Noun  육아/교육      1
#  163     요         Josa  육아/교육      1
#  164     ?  Punctuation  육아/교육      1
#
#  [165 rows x 4 columns],         0            1  type  count
#  0     군입대         Noun  보건복지      1
#  1       전     Modifier  보건복지      1
#  2     정신병         Noun  보건복지      1
#  3      검사         Noun  보건복지      1
#  4      정상         Noun  보건복지      1
#  ..    ...          ...   ...    ...
#  204  대한민국         Noun  보건복지      1
#  205   에서는         Josa  보건복지      1
#  206  태어나기         Verb  보건복지      1
#  207  싫습니다    Adjective  보건복지      1
#  208    ..  Punctuation  보건복지      1
#
#  [209 rows x 4 columns],          0            1   type  count
#  0        <  Punctuation  육아/교육      1
#  1    유아교육법         Noun  육아/교육      1
#  2        제         Noun  육아/교육      1
#  3      24조       Number  육아/교육      1
#  4      에서는      Foreign  육아/교육      1
#  ..     ...          ...    ...    ...
#  313     청원         Noun  육아/교육      1
#  314      을         Josa  육아/교육      1
#  315    드리게         Verb  육아/교육      1
#  316  되었습니다         Verb  육아/교육      1
#  317      .  Punctuation  육아/교육      1
#
#  [318 rows x 4 columns],          0            1      type  count
#  0        "  Punctuation  외교/통일/국방      1
#  1        이   Determiner  외교/통일/국방      1
#  2       라며         Noun  외교/통일/국방      1
#  3        "  Punctuation  외교/통일/국방      1
#  4      문재인         Noun  외교/통일/국방      1
#  ...    ...          ...       ...    ...
#  1574    정부         Noun  외교/통일/국방      1
#  1575    처럼         Josa  외교/통일/국방      1
#  1576  완벽하게    Adjective  외교/통일/국방      1
#  1577    배워         Verb  외교/통일/국방      1
#  1578  야합니다    Adjective  외교/통일/국방      1
#
#  [1579 rows x 4 columns],          0            1  type  count
#  0       포털         Noun  보건복지      1
#  1        을         Josa  보건복지      1
#  2       검색         Noun  보건복지      1
#  3      하다가         Verb  보건복지      1
#  4    독립유공자         Noun  보건복지      1
#  ..     ...          ...   ...    ...
#  352     하는         Verb  보건복지      1
#  353     \n      Foreign  보건복지      1
#  354      바         Noun  보건복지      1
#  355    입니다    Adjective  보건복지      1
#  356      .  Punctuation  보건복지      1
#
#  [357 rows x 4 columns],         0            1   type  count
#  0      먼저         Noun  육아/교육      1
#  1      감사         Noun  육아/교육      1
#  2    드립니다         Verb  육아/교육      1
#  3       .  Punctuation  육아/교육      1
#  4      국민         Noun  육아/교육      1
#  ..    ...          ...    ...    ...
#  432    존경         Noun  육아/교육      1
#  433    하고         Josa  육아/교육      1
#  434    사랑         Noun  육아/교육      1
#  435   합니다         Verb  육아/교육      1
#  436     .  Punctuation  육아/교육      1
#
#  [437 rows x 4 columns],           0            1      type  count
#  0        차례         Noun  외교/통일/국방      1
#  1        \n      Foreign  외교/통일/국방      1
#  2         -  Punctuation  외교/통일/국방      1
#  3       러시아         Noun  외교/통일/국방      1
#  4       PNG        Alpha  외교/통일/국방      1
#  ...     ...          ...       ...    ...
#  1197     메일         Noun  외교/통일/국방      1
#  1198      앱         Noun  외교/통일/국방      1
#  1199     에서         Josa  외교/통일/국방      1
#  1200  보냈습니다         Verb  외교/통일/국방      1
#  1201      .  Punctuation  외교/통일/국방      1
#
#  [1202 rows x 4 columns],           0            1  type  count
#  0    안녕하십니까         Noun  농산어촌      1
#  1         저         Noun  농산어촌      1
#  2         는         Josa  농산어촌      1
#  3        서울         Noun  농산어촌      1
#  4         의         Josa  농산어촌      1
#  ..      ...          ...   ...    ...
#  116       들       Suffix  농산어촌      1
#  117       께         Josa  농산어촌      1
#  118      감사         Noun  농산어촌      1
#  119    드립니다         Verb  농산어촌      1
#  120       .  Punctuation  농산어촌      1
#
#  [121 rows x 4 columns],          0            1  type  count
#  0    안녕하세요    Adjective  정치개혁      1
#  1      대통령         Noun  정치개혁      1
#  2        님       Suffix  정치개혁      1
#  3        !  Punctuation  정치개혁      1
#  4       이글         Noun  정치개혁      1
#  ..     ...          ...   ...    ...
#  508     숨김         Verb  정치개혁      1
#  509      '  Punctuation  정치개혁      1
#  510     처리         Noun  정치개혁      1
#  511  되었습니다         Verb  정치개혁      1
#  512     .)  Punctuation  정치개혁      1
#
#  [513 rows x 4 columns],         0           1 type  count
#  0      벌써        Noun  일자리      1
#  1       내  Determiner  일자리      1
#  2       일    Modifier  일자리      1
#  3      이면        Noun  일자리      1
#  4      8월      Number  일자리      1
#  ..    ...         ...  ...    ...
#  141     제    Modifier  일자리      1
#  142     고    Modifier  일자리      1
#  143    해주        Noun  일자리      1
#  144    시기        Noun  일자리      1
#  145  바랍니다        Verb  일자리      1
#
#  [146 rows x 4 columns],         0     1   type  count
#  0      가정  Noun  육아/교육      1
#  1     어린이  Noun  육아/교육      1
#  2       집  Noun  육아/교육      1
#  3      에서  Josa  육아/교육      1
#  4      영아  Noun  육아/교육      1
#  ..    ...   ...    ...    ...
#  159   크다는  Verb  육아/교육      1
#  160     것  Noun  육아/교육      1
#  161     을  Josa  육아/교육      1
#  162    믿고  Verb  육아/교육      1
#  163  싶습니다  Verb  육아/교육      1
#
#  [164 rows x 4 columns],           0            1   type  count
#  0      태어난지         Verb  육아/교육      1
#  1         한   Determiner  육아/교육      1
#  2         달         Noun  육아/교육      1
#  3         도         Noun  육아/교육      1
#  4        안되    Adjective  육아/교육      1
#  ..      ...          ...    ...    ...
#  324       .  Punctuation  육아/교육      1
#  325      고개         Noun  육아/교육      1
#  326      숙여         Verb  육아/교육      1
#  327  부탁드립니다    Adjective  육아/교육      1
#  328       .  Punctuation  육아/교육      1
#
#  [329 rows x 4 columns],        0            1 type  count
#  0    아파트         Noun  일자리      1
#  1    경비원         Noun  일자리      1
#  2      들       Suffix  일자리      1
#  3      의         Josa  일자리      1
#  4    일자리         Noun  일자리      1
#  ..   ...          ...  ...    ...
#  180    )  Punctuation  일자리      1
#  181   중개         Noun  일자리      1
#  182  수수료         Noun  일자리      1
#  183    등         Noun  일자리      1
#  184    .  Punctuation  일자리      1
#
#  [185 rows x 4 columns],          0            1   type  count
#  0    안녕하세요    Adjective  육아/교육      1
#  1       ..  Punctuation  육아/교육      1
#  2       \n      Foreign  육아/교육      1
#  3      경기도         Noun  육아/교육      1
#  4      화성시         Noun  육아/교육      1
#  ..     ...          ...    ...    ...
#  182      을         Josa  육아/교육      1
#  183    간절히    Adjective  육아/교육      1
#  184     부탁         Noun  육아/교육      1
#  185   드립니다         Verb  육아/교육      1
#  186     ..  Punctuation  육아/교육      1
#
#  [187 rows x 4 columns],         0            1  type  count
#  0       4       Number  보건복지      1
#  1       기         Noun  보건복지      1
#  2      이상         Noun  보건복지      1
#  3       의         Josa  보건복지      1
#  4      전이         Noun  보건복지      1
#  ...   ...          ...   ...    ...
#  1171   환자         Noun  보건복지      1
#  1172    가         Josa  보건복지      1
#  1173  없도록    Adjective  보건복지      1
#  1174   하라         Noun  보건복지      1
#  1175    .  Punctuation  보건복지      1
#
#  [1176 rows x 4 columns],           0          1   type  count
#  0        혹시       Noun  안전/환경      1
#  1        산업       Noun  안전/환경      1
#  2       폐기물       Noun  안전/환경      1
#  3        매립       Noun  안전/환경      1
#  4         장     Suffix  안전/환경      1
#  ..      ...        ...    ...    ...
#  500      마음       Noun  안전/환경      1
#  501      놓고       Verb  안전/환경      1
#  502    뛰어놀수       Verb  안전/환경      1
#  503      있게  Adjective  안전/환경      1
#  504  부탁드립니다  Adjective  안전/환경      1
#
#  [505 rows x 4 columns],           0            1  type  count
#  0    안녕하십니까         Noun  보건복지      1
#  1         ?  Punctuation  보건복지      1
#  2        \n      Foreign  보건복지      1
#  3         저         Noun  보건복지      1
#  4         는         Josa  보건복지      1
#  ..      ...          ...   ...    ...
#  273      하고         Josa  보건복지      1
#  274       더         Noun  보건복지      1
#  275      노력         Noun  보건복지      1
#  276   하겠습니다         Verb  보건복지      1
#  277       .  Punctuation  보건복지      1
#
#  [278 rows x 4 columns],          0            1   type  count
#  0      소규모         Noun  육아/교육      1
#  1       영아         Noun  육아/교육      1
#  2       중심         Noun  육아/교육      1
#  3     어린이집         Noun  육아/교육      1
#  4       교사         Noun  육아/교육      1
#  ..     ...          ...    ...    ...
#  189      을         Josa  육아/교육      1
#  190      꼭         Noun  육아/교육      1
#  191  들어주시기         Verb  육아/교육      1
#  192   바랍니다         Verb  육아/교육      1
#  193      .  Punctuation  육아/교육      1
#
#  [194 rows x 4 columns],           0            1  type  count
#  0    안녕하십니까         Noun  보건복지      1
#  1         ?  Punctuation  보건복지      1
#  2        \n      Foreign  보건복지      1
#  3         저         Noun  보건복지      1
#  4         는         Josa  보건복지      1
#  ..      ...          ...   ...    ...
#  273      하고         Josa  보건복지      1
#  274       더         Noun  보건복지      1
#  275      노력         Noun  보건복지      1
#  276   하겠습니다         Verb  보건복지      1
#  277       .  Punctuation  보건복지      1
#
#  [278 rows x 4 columns],          0            1 type  count
#  0    안녕하세요    Adjective   행정      1
#  1      문재인         Noun   행정      1
#  2      대통령         Noun   행정      1
#  3        님       Suffix   행정      1
#  4        .  Punctuation   행정      1
#  ..     ...          ...  ...    ...
#  296      히       Adverb   행정      1
#  297  믿겠습니다         Verb   행정      1
#  298      .  Punctuation   행정      1
#  299  감사합니다         Verb   행정      1
#  300      .  Punctuation   행정      1
#
#  [301 rows x 4 columns],         0            1 type  count
#  0     생리대         Noun   행정      1
#  1      안전         Noun   행정      1
#  2      검증         Noun   행정      1
#  3     위원회         Noun   행정      1
#  4       여     Modifier   행정      1
#  ..    ...          ...  ...    ...
#  133     .  Punctuation   행정      1
#  134     일     Modifier   행정      1
#  135   똑바로         Noun   행정      1
#  136  하십시요         Verb   행정      1
#  137     !  Punctuation   행정      1
#
#  [138 rows x 4 columns]]

# %%
# "저장공간" 변수의 내용을 데이터프레임 형식으로 변환해서 "분석통합" 변수에 저장한다.
분석통합 = pd.concat(저장공간)

# %%
# "분석통합" 변수의 저장 내용 확인
분석통합
# Out:
#         0            1   type  count
# 0      올해         Noun  육아/교육      1
# 1     보육료         Noun  육아/교육      1
# 2       가         Josa  육아/교육      1
# 3     오르지         Verb  육아/교육      1
# 4    않았는데         Verb  육아/교육      1
# ..    ...          ...    ...    ...
# 133     .  Punctuation     행정      1
# 134     일     Modifier     행정      1
# 135   똑바로         Noun     행정      1
# 136  하십시요         Verb     행정      1
# 137     !  Punctuation     행정      1
#
# [8782 rows x 4 columns]

# %%
# "분석통합" 변수의 컬럼(열) 이름 변경
분석통합.columns = ["형태소", "품사", "분류", "카운트"]

# %%
# "분석통합" 변수의 저장 내용 확인
분석통합
# Out:
#       형태소           품사     분류  카운트
# 0      올해         Noun  육아/교육    1
# 1     보육료         Noun  육아/교육    1
# 2       가         Josa  육아/교육    1
# 3     오르지         Verb  육아/교육    1
# 4    않았는데         Verb  육아/교육    1
# ..    ...          ...    ...  ...
# 133     .  Punctuation     행정    1
# 134     일     Modifier     행정    1
# 135   똑바로         Noun     행정    1
# 136  하십시요         Verb     행정    1
# 137     !  Punctuation     행정    1
#
# [8782 rows x 4 columns]

# %%
# "분석통합" 변수의 내용을 형태소, 품사, 분류가 같은 것을 합치고, 카운트의 총합을 구해서 "그룹통합" 변수에 저장한다.
그룹통합 = 분석통합.groupby(['형태소', '품사', "분류"])['카운트'].sum()

# %%
# "그룹통합" 변수의 저장 내용 확인
그룹통합
# Out:
# 형태소    품사         분류
# \n     Foreign    농산어촌         1
#                   보건복지        18
#                   안전/환경       23
#                   외교/통일/국방    45
#                   육아/교육       25
#                               ..
# 힘      Noun       외교/통일/국방     3
# 힘들고    Adjective  육아/교육        1
#                   정치개혁         1
# 힘들어지고  Adjective  육아/교육        2
# 힘쓸     Verb       육아/교육        1
# Name: 카운트, Length: 3732, dtype: int64

# %%
# "그룹통합" 변수의 내용을 데이터프레임 형식으로 변환해서 "그룹통합" 변수에 저장한다.
그룹통합 = pd.DataFrame(그룹통합)

# %%
# "그룹통합" 변수의 저장 내용 확인
그룹통합
# Out:
#                           카운트
# 형태소   품사        분류
# \n    Foreign   농산어촌        1
#                 보건복지       18
#                 안전/환경      23
#                 외교/통일/국방   45
#                 육아/교육      25
# ...                       ...
# 힘     Noun      외교/통일/국방    3
# 힘들고   Adjective 육아/교육       1
#                 정치개혁        1
# 힘들어지고 Adjective 육아/교육       2
# 힘쓸    Verb      육아/교육       1
#
# [3732 rows x 1 columns]

# %%
# "그룹통합" 변수의 내용을 "형태소분석결과.csv" 파일로 저장한다.
# header는 컬럼(열) 정보의 포함 여부이다.
# encoding은 문자코드를 선택하는 것이다. python에서는 기본적으로 utf-8(유니코드)를 사용한다.

그룹통합.to_csv('형태소분석결과_1.csv', header='true', encoding='utf-8')
